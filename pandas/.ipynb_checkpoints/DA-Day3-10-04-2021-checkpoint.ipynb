# %%
import pandas as pd

# %%
print(dir(pd))
# Out:
# ['Categorical', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'ExcelFile', 'ExcelWriter', 'Expr', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int64Index', 'Interval', 'IntervalIndex', 'MultiIndex', 'NaT', 'Panel', 'Panel4D', 'Period', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseArray', 'SparseDataFrame', 'SparseList', 'SparseSeries', 'Term', 'TimeGrouper', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt64Index', 'WidePanel', '_DeprecatedModule', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_hashtable', '_lib', '_libs', '_np_version_under1p10', '_np_version_under1p11', '_np_version_under1p12', '_np_version_under1p13', '_np_version_under1p14', '_np_version_under1p15', '_tslib', '_version', 'api', 'bdate_range', 'compat', 'concat', 'core', 'crosstab', 'cut', 'date_range', 'datetime', 'datetools', 'describe_option', 'errors', 'eval', 'ewma', '
# ...

# %%
help(pd.Series)
# Out:
# Help on class Series in module pandas.core.series:
#
# class Series(pandas.core.base.IndexOpsMixin, pandas.core.generic.NDFrame)
#  |  One-dimensional ndarray with axis labels (including time series).
#  |
#  |  Labels need not be unique but must be a hashable type. The object
#  |  supports both integer- and label-based indexing and provides a host of
#  |  methods for performing operations involving the index. Statistical
#  |  methods from ndarray have been overridden to automatically exclude
#  |  missing data (currently represented as NaN).
#  |
#  |  Operations between Series (+, -, /, *, **) align values based on their
#  |  associated index values-- they need not be the same length. The result
#  |  index will be the sorted union of the two indexes.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like, dict, or scalar value
#  |      Contains data stored in Series
#  |  index : array-like or Index (1d)
# ...

# %% [markdown]
# s1 = pd.Series([10,11,12,13,14])
# s1

# %%
s1 = pd.Series([10,11,12,13,14]) 
s1
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# dtype: int64

# %%
dict3 ={'a':11,'b':'ab','c':12,'d':'de'}

# %%
s3=pd.Series(dict3)
s3
# Out:
# a    11
# b    ab
# c    12
# d    de
# dtype: object

# %%
import numpy as np
s4 =pd.Series(np.array([1,2,3,4,5]))
s4
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
s5=pd.Series([1,2,3,4,5])
s6=pd.Series([6,7,8,9,1])

# %%
print(s5 + s6)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4     6
# dtype: int64

# %%
print(s5-s6)
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4    4
# dtype: int64

# %%
print(s5/s6)
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    5.000000
# dtype: float64

# %%
s7=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s7
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dict1={'Trainer':['vasanthi','lakshmi','vijay'],'sub':['python','DS','C'],'id':[123,234,345]}
df=pd.DataFrame(dict1,index=['a','b','c'])
df
# Out:
#     Trainer   id     sub
# a  vasanthi  123  python
# b   lakshmi  234      DS
# c     vijay  345       C

# %%
df[0:1]
# Out:
#     Trainer   id     sub
# a  vasanthi  123  python

# %%
df[0:2]
# Out:
#     Trainer   id     sub
# a  vasanthi  123  python
# b   lakshmi  234      DS

# %%
df['Trainer']
# Out:
# a    vasanthi
# b     lakshmi
# c       vijay
# Name: Trainer, dtype: object

# %%
df['id']
# Out:
# a    123
# b    234
# c    345
# Name: id, dtype: int64

# %%
df['id'][2]
# Out:
# 345

# %%
df['id'][1]
# Out:
# 234

# %%
df.iloc[2]
# Out:
# Trainer    vijay
# id           345
# sub            C
# Name: c, dtype: object

# %%
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.loc['a':'b',['Trainer','sub']]
# Out:
#     Trainer     sub
# a  vasanthi  python
# b   lakshmi      DS

# %%
df.iloc[0:2,[0,1]]
# Out:
#     Trainer   id
# a  vasanthi  123
# b   lakshmi  234

# %%
dict1={'sports':['Crt','hockey','Coco'],'Score':[9,7,8],'Team':['CSE_team','ECE_team','it_team']}
df=pd.DataFrame(dict1,index=['A','B','C'])
df
# Out:
#    Score      Team  sports
# A      9  CSE_team     Crt
# B      7  ECE_team  hockey
# C      8   it_team    Coco

# %%
pd.concat([df,df])
# Out:
#    Score      Team  sports
# A      9  CSE_team     Crt
# B      7  ECE_team  hockey
# C      8   it_team    Coco
# A      9  CSE_team     Crt
# B      7  ECE_team  hockey
# C      8   it_team    Coco

# %% [markdown]
# ### Adding a row and column

# %%
df.append({'Score':10,'Team':'it_team','sports':'crt'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0c1792be9684> in <module>()
# ----> 1 df.append({'Score':10,'Team':'it_team','sports':'crt'})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity)
#    5162                 other = Series(other)
#    5163             if other.name is None and not ignore_index:
# -> 5164                 raise TypeError('Can only append a Series if ignore_index=True'
#    5165                                 ' or if the Series has a name')
#    5166
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name

# %%
df.append({'Score':10,'Team':'it_team','sports':'crt'},ignore_index=True)
df

# %% [markdown]
# # Adding Column

# %%
df['win/loss']=['Win','Loss','Win']

# %%
df
# Out:
#    Score      Team  sports
# A      9  CSE_team     Crt
# B      7  ECE_team  hockey
# C      8   it_team    Coco

# %%
df=pd.read_csv('market_fact.csv')
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df.head(10)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
# 9  Ord_4725   Prod_6  SHP_6593  Cust_1641    57.2200      0.07
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0              23   -30.51           3.60                 0.56
# 1              13     4.56           0.93                 0.54
# 2              26  1148.90           2.50                 0.59
# ...

# %%
df.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
df.tail(10)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8389  Ord_4444  Prod_13  SHP_6192  Cust_1519   159.4100      0.00
# 8390  Ord_5435  Prod_16  SHP_7594  Cust_1798   316.9900      0.04
# 8391  Ord_5435   Prod_4  SHP_7594  Cust_1798  1991.8985      0.07
# 8392  Ord_5384   Prod_9  SHP_7519  Cust_1798   181.5000      0.08
# 8393  Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8389              44   34.68           0.98                 0.52
# 8390              47 -276.54           8.37                 0.58
# ...

# %%
df.sample()
# Out:
#        Ord_id Prod_id  Ship_id  Cust_id    Sales  Discount  Order_Quantity  \
# 2441  Ord_309  Prod_2  SHP_415  Cust_77  2700.41      0.08              10
#
#       Profit  Shipping_Cost  Product_Base_Margin
# 2441  258.01          23.19                 0.59

# %%
df.sample(5)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 6401  Ord_1251   Prod_5  SHP_1728   Cust_469  8958.4600      0.02
# 4800   Ord_705   Prod_4   SHP_965   Cust_231  1580.6005      0.07
# 6294  Ord_3040   Prod_2  SHP_4218  Cust_1140   374.3800      0.03
# 2428  Ord_2570  Prod_11  SHP_3520   Cust_968  2527.7920      0.09
# 3605  Ord_3487   Prod_7  SHP_4828  Cust_1191    15.6000      0.09
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 6401              41  2593.14          21.21                 0.59
# 4800              30   303.53           2.79                 0.56
# 6294              42    -1.16           3.50                 0.58
# 2428              23  -335.32          52.42                 0.74
# 3605               5     1.67           0.78                 0.52

# %%
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %%
df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
df.mean()
# Out:
# Sales                  1775.878179
# Discount                  0.049671
# Order_Quantity           25.571735
# Profit                  181.184424
# Shipping_Cost            12.838557
# Product_Base_Margin       0.512513
# dtype: float64

# %%
df['Sales'].mean()
# Out:
# 1775.8781788308156

# %%
df.shape
# Out:
# (8399, 10)

# %%
df['Sales']>30000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8369    False
# 8370    False
# 8371    False
# 8372    False
# 8373    False
# 8374    False
# 8375    False
# 8376    False
# 8377    False
# 8378    False
# 8379    False
# 8380    False
# 8381    False
# 8382    False
# 8383    False
# 8384    False
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# 8390    False
# 8391    False
# 8392    False
# 8393    False
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# ...

# %%
df[df['Sales']>30000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 1835               8   3852.19          24.49                 0.39
# 2349               9   3992.52          24.49                 0.37
# 2738              13  27220.69          24.49                 0.39
# 3784               7    102.61          24.49                 0.39

# %%
df[df['Sales']>30000].count()
# Out:
# Ord_id                 4
# Prod_id                4
# Ship_id                4
# Cust_id                4
# Sales                  4
# Discount               4
# Order_Quantity         4
# Profit                 4
# Shipping_Cost          4
# Product_Base_Margin    4
# dtype: int64

# %%
df[(df['Sales']>25000) & (df['Sales']<30000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 2216  Ord_4216  Prod_14  SHP_5881  Cust_1432  26126.92      0.04
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 2259  Ord_1978  Prod_17  SHP_2703   Cust_725  25312.00      0.01
# 2680  Ord_1963  Prod_11  SHP_2687   Cust_732  26622.55      0.08
# 4124  Ord_2345   Prod_3  SHP_3218   Cust_937  25409.63      0.02
# 4291   Ord_138  Prod_10   SHP_185    Cust_92  26133.39      0.04
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 4963  Ord_4161  Prod_17  SHP_5798  Cust_1421  25313.34      0.05
# 5042  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6245   Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 6660  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# ...

# %%
df[(df['Sales']>25000) & (df['Sales']<30000)].count()
# Out:
# Ord_id                 19
# Prod_id                19
# Ship_id                19
# Cust_id                19
# Sales                  19
# Discount               19
# Order_Quantity         19
# Profit                 19
# Shipping_Cost          19
# Product_Base_Margin    19
# dtype: int64

# %%
df['Prod_id'].value_counts()
# Out:
# Prod_6     1225
# Prod_3      915
# Prod_4      883
# Prod_5      788
# Prod_8      758
# Prod_13     633
# Prod_1      546
# Prod_2      434
# Prod_15     386
# Prod_11     361
# Prod_17     337
# Prod_12     288
# Prod_9      246
# Prod_10     189
# Prod_7      179
# Prod_16     144
# Prod_14      87
# Name: Prod_id, dtype: int64

# %%
df[df['Prod_id']=='Prod_14'].count()
# Out:
# Ord_id                 87
# Prod_id                87
# Ship_id                87
# Cust_id                87
# Sales                  87
# Discount               87
# Order_Quantity         87
# Profit                 87
# Shipping_Cost          87
# Product_Base_Margin    87
# dtype: int64

# %%
df['Prod_id']=='Prod_14'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8369    False
# 8370    False
# 8371    False
# 8372    False
# 8373    False
# 8374    False
# 8375    False
# 8376    False
# 8377    False
# 8378    False
# 8379    False
# 8380    False
# 8381    False
# 8382    False
# 8383    False
# 8384    False
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# 8390    False
# 8391    False
# 8392    False
# 8393    False
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# ...

# %%
df.sort_values(by = ['Sales'])
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# 5166  Ord_1109  Prod_13  SHP_1531   Cust_429      3.63      0.03
# 4510  Ord_1751  Prod_13  SHP_2427   Cust_597      3.77      0.09
# 45    Ord_4768  Prod_12  SHP_6650  Cust_1579      3.85      0.08
# 3874  Ord_2380   Prod_7  SHP_3268   Cust_953      3.96      0.10
# 2453  Ord_2890   Prod_7  SHP_3987  Cust_1054      4.94      0.10
# 4754  Ord_2506   Prod_7  SHP_5853  Cust_1415      4.97      0.04
# 1359   Ord_104  Prod_16   SHP_142    Cust_62      4.99      0.04
# 4063   Ord_834  Prod_16  SHP_1142   Cust_269      5.06      0.01
# ...

# %%
df.sort_values(by = ['Sales'],ascending=False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 7547  Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6245   Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 8217  Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 7091   Ord_911  Prod_10  SHP_1255   Cust_302  28180.08      0.02
# 7318   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# ...

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
df.sort_values(by = ['Sales'],ascending=False,inplace=True)

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 7547  Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6245   Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 8217  Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 7091   Ord_911  Prod_10  SHP_1255   Cust_302  28180.08      0.02
# 7318   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# ...
