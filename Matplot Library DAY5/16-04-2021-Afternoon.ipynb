# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
img1=plt.imread('img.jpg')
img1
# Out:
# array([[[144, 177, 182],
#         [149, 182, 187],
#         [158, 191, 196],
#         ...,
#         [ 52,  52,  50],
#         [ 44,  44,  42],
#         [ 39,  39,  37]],
#
#        [[139, 172, 177],
#         [136, 169, 174],
#         [134, 165, 170],
#         ...,
#         [ 52,  52,  50],
#         [ 49,  49,  47],
#         [ 48,  48,  46]],
#
#        [[151, 182, 187],
#         [143, 174, 179],
#         [125, 154, 160],
#         ...,
#         [ 52,  52,  50],
#         [ 55,  55,  53],
#         [ 57,  57,  55]],
#
#        ...,
#
#        [[ 66,  77,  11],
#         [ 73,  84,  18],
#         [ 84,  95,  27],
#         ...,
#         [193, 199,  47],
#         [197, 204,  48],
#         [200, 206,  48]],
#
#        [[ 67,  79,   7],
#         [ 73,  85,  13],
#         [ 83,  95,  21],
#         ...,
#         [191, 197,  47],
#         [195, 202,  47],
#         [196, 203,  47]],
#
#        [[ 70,  82,   6],
#         [ 76,  88,  12],
#         [ 85,  98,  19],
# ...

# %%
img1=plt.imshow(plt.imread('img.jpg'))

# %%
plt.imshow(img1[250:750,1000:2500])
